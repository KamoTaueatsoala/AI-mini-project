# %% [markdown]
# <a href="https://colab.research.google.com/github/KamoTaueatsoala/AI-mini-project/blob/main/irrigation_semi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""irrigation.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/github/KamoTaueatsoala/ML-Projects/blob/main/irrigation.ipynb
"""

import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score
import matplotlib.pyplot as plt

# Constants
MAX_SENSOR_VALUE = 4095
MIN_TEMP = 10.0
MAX_TEMP = 45.0
MAX_HUMIDITY = 100.0

# Soil moisture thresholds
IN_WATER_THRESHOLD = 1400    # Sensor in water
WET_MOIST_THRESHOLD = 3400   # Wet to moist soil
OPEN_AIR_MIN = 3500          # Open air/dry soil
OPEN_AIR_MAX = 3699          # Open air maximum

def generate_water(soil, temp, humidity, hour):
    """Adjusted water calculation for realistic volumes suitable for parsley in typical gardens (e.g., 50-150 ml)"""
    if soil <= IN_WATER_THRESHOLD:
        return 0.0

    # Normalized soil moisture (0=wet, 1=dry)
    soil_norm = (soil - IN_WATER_THRESHOLD) / (OPEN_AIR_MAX - IN_WATER_THRESHOLD)

    # Base water needs - scaled for parsley, capped at realistic levels
    if soil >= OPEN_AIR_MIN:
        base_water = 50.0 + soil_norm * 100.0  # 50-150 ml for dry soil
    else:
        base_water = 10.0 + soil_norm * 40.0   # 10-50 ml for moist soil
    base_water = min(base_water, 150.0)  # Cap maximum at 150 ml

    # Environmental adjustments, moderated for better balance
    temp_adj = 5.0 * ((temp - MIN_TEMP) / (MAX_TEMP - MIN_TEMP))  # Reduced sensitivity
    hum_adj = 3.0 * (1 - (humidity / MAX_HUMIDITY))  # Reduced humidity impact

    # Time of day effect, moderated
    hour_adj = 1.0 * np.cos((hour - 14) * np.pi / 12)

    # Combine factors - soil dryness has strongest influence, but capped
    water_ml = base_water + temp_adj + hum_adj + hour_adj
    return max(0, min(water_ml, 150.0))  # Ensure output stays within 0-150 ml

def generate_features(soil, temp, humidity, hour):
    """Generate features with proper soil-water relationship"""
    temp_norm = (temp - MIN_TEMP) / (MAX_TEMP - MIN_TEMP)
    hum_norm = humidity / MAX_HUMIDITY
    soil_norm = (soil - IN_WATER_THRESHOLD) / (OPEN_AIR_MAX - IN_WATER_THRESHOLD)  # 0-1 scale

    return np.column_stack((
        soil_norm,  # Direct soil dryness measure
        temp_norm,
        hum_norm,
        np.sin(hour * np.pi / 12),
        np.cos(hour * np.pi / 12),
        soil_norm * temp_norm,  # Interaction terms
        soil_norm * hum_norm,
        temp_norm * hum_norm
    ))

def load_data():
    """Generate training data with increased wet soil representation"""
    np.random.seed(42)
    num_samples = 30000

    # Generate soil values with balanced distribution
    soil = np.concatenate([
        np.random.randint(0, IN_WATER_THRESHOLD, num_samples//3),  # 33% wet soil
        np.random.triangular(IN_WATER_THRESHOLD, WET_MOIST_THRESHOLD, OPEN_AIR_MIN, num_samples//3),
        np.random.triangular(OPEN_AIR_MIN, OPEN_AIR_MAX, OPEN_AIR_MAX+300, num_samples//3)
    ])[:num_samples]  # Ensure correct size

    # Environmental conditions
    temp = np.random.normal(25, 10, num_samples)
    temp = np.clip(temp, MIN_TEMP, MAX_TEMP)
    humidity = np.random.normal(50, 25, num_samples)
    humidity = np.clip(humidity, 10, MAX_HUMIDITY)
    hour = np.random.randint(0, 24, num_samples)

    # Add sensor noise
    soil += np.random.normal(0, 20, size=soil.shape).astype(int)  # Reduced noise
    soil = np.clip(soil, 0, MAX_SENSOR_VALUE)

    water = np.array([generate_water(s,t,h,hr) for s,t,h,hr in zip(soil, temp, humidity, hour)])

    # Visualization
    plt.figure(figsize=(15,6))
    plt.scatter(soil, water, alpha=0.3)
    plt.axvline(IN_WATER_THRESHOLD, color='r', linestyle='--', label='In Water')
    plt.axvline(WET_MOIST_THRESHOLD, color='g', linestyle='--', label='Wet-Moist Transition')
    plt.axvline(OPEN_AIR_MIN, color='b', linestyle='--', label='Open Air/Dry Soil')
    plt.title("Soil ADC vs Water Need Relationship")
    plt.xlabel("Soil ADC Value")
    plt.ylabel("Water Need (ml)")
    plt.legend()
    plt.show()

    X = generate_features(soil, temp, humidity, hour)
    y = water.reshape(-1, 1)
    return train_test_split(X, y, test_size=0.15, random_state=42)

# Load data
X_train, X_test, y_train, y_test = load_data()

# Enhanced model with fixed learning rate
def create_model():
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(8,)),
        tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dense(1, activation='linear')
    ])

    model.compile(
        optimizer=tf.keras.optimizers.AdamW(learning_rate=0.005),
        loss=tf.keras.losses.Huber(delta=1.0),
        metrics=['mae', tf.keras.metrics.RootMeanSquaredError()])

    return model

model = create_model()

# Callbacks
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=30,
    restore_best_weights=True)

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=10,
    min_lr=1e-5,
    verbose=1)

history = model.fit(
    X_train, y_train,
    epochs=300,
    batch_size=128,
    validation_data=(X_test, y_test),
    callbacks=[early_stop, reduce_lr],
    verbose=1)

# Evaluation
y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"\nModel Metrics:")
print(f"- MAE: {mae:.4f} ml")
print(f"- R²: {r2:.4f}")

# Visualization
plt.figure(figsize=(10, 8))
plt.scatter(y_test, y_pred, alpha=0.4, c='blue', label='Predictions')
max_water = max(np.max(y_test), np.max(y_pred)) * 1.1
plt.plot([0, max_water], [0, max_water], 'r--', label='Perfect Prediction')
plt.fill_between([0, max_water], [0-mae, max_water-mae], [0+mae, max_water+mae],
                color='orange', alpha=0.1, label=f'MAE: {mae:.2f} ml')
plt.xlabel('Actual Water Need (ml)')
plt.ylabel('Predicted Water Need (ml)')
plt.title(f'Predicted vs Actual\nR²: {r2:.3f}')
plt.legend()
plt.grid(True)
plt.show()

# TFLite conversion (FLOAT32 version)
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = []  # Disable quantization
converter.target_spec.supported_types = [tf.float32]  # Force float32
tflite_model = converter.convert()

with open('water_model.tflite', 'wb') as f:
    f.write(tflite_model)

print("\nModel size:", len(tflite_model), "bytes")

# Generate C header
from subprocess import call
call("echo 'const unsigned char model[] = {' > model.h", shell=True)
call("cat water_model.tflite | xxd -i >> model.h", shell=True)
call("echo '};' >> model.h", shell=True)
call("echo 'const unsigned int model_len = sizeof(model);' >> model.h", shell=True)
# Out:
# Epoch 1/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 25.1821 - mae: 25.4783 - root_mean_squared_error: 43.2283 - val_loss: 36.1427 - val_mae: 36.4100 - val_root_mean_squared_error: 55.0450 - learning_rate: 0.0050
# Epoch 2/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.8556 - mae: 9.0782 - root_mean_squared_error: 16.0515 - val_loss: 20.7554 - val_mae: 21.0028 - val_root_mean_squared_error: 30.2138 - learning_rate: 0.0050
# Epoch 3/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 6.4196 - mae: 6.6307 - root_mean_squared_error: 11.6150 - val_loss: 4.1085 - val_mae: 4.3013 - val_root_mean_squared_error: 6.9873 - learning_rate: 0.0050
# Epoch 4/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.3686 - mae: 5.5419 - root_mean_squared_error: 10.1865 - val_loss: 5.5119 - val_mae: 5.7196 - val_root_mean_squared_error: 8.7499 - learning_rate: 0.0050
# Epoch 5/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 5.7843 - mae: 5.9690 - root_mean_squared_error: 10.8689 - val_loss: 2.0419 - val_mae: 2.1499 - val_root_mean_squared_error: 5.6368 - learning_rate: 0.0050
# Epoch 6/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 4.7898 - mae: 4.9506 - root_mean_squared_error: 9.3279 - val_loss: 4.6782 - val_mae: 4.8535 - val_root_mean_squared_error: 10.7279 - learning_rate: 0.0050
# Epoch 7/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.0474 - mae: 5.2213 - root_mean_squared_error: 9.9101 - val_loss: 2.8131 - val_mae: 2.8824 - val_root_mean_squared_error: 6.2458 - learning_rate: 0.0050
# Epoch 8/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.2589 - mae: 4.3988 - root_mean_squared_error: 8.8821 - val_loss: 6.8692 - val_mae: 7.1031 - val_root_mean_squared_error: 9.9487 - learning_rate: 0.0050
# Epoch 9/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 5.0925 - mae: 5.2554 - root_mean_squared_error: 10.1121 - val_loss: 1.9820 - val_mae: 2.0812 - val_root_mean_squared_error: 5.3654 - learning_rate: 0.0050
# Epoch 10/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 4.2257 - mae: 4.3657 - root_mean_squared_error: 8.4541 - val_loss: 3.0986 - val_mae: 3.2180 - val_root_mean_squared_error: 6.8678 - learning_rate: 0.0050
# Epoch 11/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.9007 - mae: 4.0428 - root_mean_squared_error: 8.9631 - val_loss: 4.5144 - val_mae: 4.6296 - val_root_mean_squared_error: 14.5549 - learning_rate: 0.0050
# Epoch 12/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.6791 - mae: 3.8097 - root_mean_squared_error: 8.1260 - val_loss: 2.5943 - val_mae: 2.7284 - val_root_mean_squared_error: 4.3034 - learning_rate: 0.0050
# Epoch 13/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.7564 - mae: 3.8890 - root_mean_squared_error: 8.9558 - val_loss: 2.1555 - val_mae: 2.2897 - val_root_mean_squared_error: 4.2797 - learning_rate: 0.0050
# Epoch 14/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.5348 - mae: 3.6731 - root_mean_squared_error: 8.0550 - val_loss: 1.1765 - val_mae: 1.2548 - val_root_mean_squared_error: 3.5540 - learning_rate: 0.0050
# Epoch 15/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.4714 - mae: 3.6205 - root_mean_squared_error: 7.6858 - val_loss: 1.5245 - val_mae: 1.5878 - val_root_mean_squared_error: 6.5371 - learning_rate: 0.0050
# Epoch 16/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 3.5785 - mae: 3.7282 - root_mean_squared_error: 8.7557 - val_loss: 1.4324 - val_mae: 1.5281 - val_root_mean_squared_error: 5.8942 - learning_rate: 0.0050
# Epoch 17/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.4530 - mae: 3.5986 - root_mean_squared_error: 8.2438 - val_loss: 1.2296 - val_mae: 1.3525 - val_root_mean_squared_error: 2.3694 - learning_rate: 0.0050
# Epoch 18/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 3.0174 - mae: 3.1675 - root_mean_squared_error: 7.1955 - val_loss: 1.7835 - val_mae: 1.9147 - val_root_mean_squared_error: 5.7597 - learning_rate: 0.0050
# Epoch 19/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.0749 - mae: 3.2226 - root_mean_squared_error: 7.7572 - val_loss: 3.8563 - val_mae: 4.0538 - val_root_mean_squared_error: 5.5644 - learning_rate: 0.0050
# Epoch 20/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.2287 - mae: 3.3807 - root_mean_squared_error: 8.3562 - val_loss: 1.5497 - val_mae: 1.6793 - val_root_mean_squared_error: 4.1054 - learning_rate: 0.0050
# Epoch 21/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.8322 - mae: 2.9864 - root_mean_squared_error: 6.7476 - val_loss: 2.1294 - val_mae: 2.2359 - val_root_mean_squared_error: 5.1121 - learning_rate: 0.0050
# Epoch 22/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 3.0189 - mae: 3.1812 - root_mean_squared_error: 7.9857 - val_loss: 1.5484 - val_mae: 1.6908 - val_root_mean_squared_error: 3.5872 - learning_rate: 0.0050
# Epoch 23/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.6465 - mae: 2.8162 - root_mean_squared_error: 6.8633 - val_loss: 2.5514 - val_mae: 2.7793 - val_root_mean_squared_error: 5.0393 - learning_rate: 0.0050
# Epoch 24/300
# 195/200 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5352 - mae: 2.7130 - root_mean_squared_error: 6.3274
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0024999999441206455.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.5348 - mae: 2.7126 - root_mean_squared_error: 6.3305 - val_loss: 2.7377 - val_mae: 2.9697 - val_root_mean_squared_error: 5.0567 - learning_rate: 0.0050
# Epoch 25/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 2.1232 - mae: 2.2761 - root_mean_squared_error: 5.8699 - val_loss: 1.5278 - val_mae: 1.7313 - val_root_mean_squared_error: 3.1377 - learning_rate: 0.0025
# Epoch 26/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.8967 - mae: 2.0482 - root_mean_squared_error: 5.2133 - val_loss: 1.2289 - val_mae: 1.3988 - val_root_mean_squared_error: 2.6969 - learning_rate: 0.0025
# Epoch 27/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 1.7576 - mae: 1.9076 - root_mean_squared_error: 5.2768 - val_loss: 0.8874 - val_mae: 1.0190 - val_root_mean_squared_error: 3.9625 - learning_rate: 0.0025
# Epoch 28/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.6891 - mae: 1.8432 - root_mean_squared_error: 4.6925 - val_loss: 1.4737 - val_mae: 1.6009 - val_root_mean_squared_error: 3.2552 - learning_rate: 0.0025
# Epoch 29/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.6198 - mae: 1.7754 - root_mean_squared_error: 5.0438 - val_loss: 0.4235 - val_mae: 0.5101 - val_root_mean_squared_error: 1.9025 - learning_rate: 0.0025
# Epoch 30/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.4733 - mae: 1.6388 - root_mean_squared_error: 4.7499 - val_loss: 1.3163 - val_mae: 1.5004 - val_root_mean_squared_error: 4.2094 - learning_rate: 0.0025
# Epoch 31/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.4559 - mae: 1.6237 - root_mean_squared_error: 5.1642 - val_loss: 0.8624 - val_mae: 1.0292 - val_root_mean_squared_error: 2.1339 - learning_rate: 0.0025
# Epoch 32/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.2511 - mae: 1.4165 - root_mean_squared_error: 4.4863 - val_loss: 0.9300 - val_mae: 1.1158 - val_root_mean_squared_error: 3.2904 - learning_rate: 0.0025
# Epoch 33/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.2310 - mae: 1.3980 - root_mean_squared_error: 4.9109 - val_loss: 0.9495 - val_mae: 1.1184 - val_root_mean_squared_error: 3.6555 - learning_rate: 0.0025
# Epoch 34/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1522 - mae: 1.3017 - root_mean_squared_error: 4.8018 - val_loss: 0.7669 - val_mae: 0.9010 - val_root_mean_squared_error: 3.8032 - learning_rate: 0.0025
# Epoch 35/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1515 - mae: 1.3241 - root_mean_squared_error: 5.2404 - val_loss: 0.7872 - val_mae: 1.0030 - val_root_mean_squared_error: 3.5671 - learning_rate: 0.0025
# Epoch 36/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.9199 - mae: 1.0926 - root_mean_squared_error: 4.0450 - val_loss: 0.4866 - val_mae: 0.6678 - val_root_mean_squared_error: 2.0398 - learning_rate: 0.0025
# Epoch 37/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1.0030 - mae: 1.1647 - root_mean_squared_error: 5.2209 - val_loss: 1.4268 - val_mae: 1.6431 - val_root_mean_squared_error: 8.2197 - learning_rate: 0.0025
# Epoch 38/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.8249 - mae: 0.9690 - root_mean_squared_error: 4.6609 - val_loss: 0.6983 - val_mae: 0.8515 - val_root_mean_squared_error: 3.5289 - learning_rate: 0.0025
# Epoch 39/300
# 199/200 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8399 - mae: 0.9801 - root_mean_squared_error: 4.9306
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0012499999720603228.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.8393 - mae: 0.9796 - root_mean_squared_error: 4.9259 - val_loss: 0.8695 - val_mae: 1.0510 - val_root_mean_squared_error: 2.9987 - learning_rate: 0.0025
# Epoch 40/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.7720 - mae: 0.9159 - root_mean_squared_error: 3.8546 - val_loss: 0.5231 - val_mae: 0.6815 - val_root_mean_squared_error: 2.2966 - learning_rate: 0.0012
# Epoch 41/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6570 - mae: 0.7733 - root_mean_squared_error: 4.0018 - val_loss: 0.4669 - val_mae: 0.5773 - val_root_mean_squared_error: 2.6083 - learning_rate: 0.0012
# Epoch 42/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6858 - mae: 0.8128 - root_mean_squared_error: 4.1140 - val_loss: 0.5888 - val_mae: 0.6947 - val_root_mean_squared_error: 1.7513 - learning_rate: 0.0012
# Epoch 43/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6882 - mae: 0.8038 - root_mean_squared_error: 4.3274 - val_loss: 0.2907 - val_mae: 0.2887 - val_root_mean_squared_error: 1.8719 - learning_rate: 0.0012
# Epoch 44/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6974 - mae: 0.8169 - root_mean_squared_error: 4.4367 - val_loss: 0.6960 - val_mae: 0.8106 - val_root_mean_squared_error: 2.1559 - learning_rate: 0.0012
# Epoch 45/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6420 - mae: 0.7652 - root_mean_squared_error: 3.7477 - val_loss: 0.3718 - val_mae: 0.5688 - val_root_mean_squared_error: 1.3752 - learning_rate: 0.0012
# Epoch 46/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6046 - mae: 0.7279 - root_mean_squared_error: 3.7847 - val_loss: 0.5394 - val_mae: 0.7105 - val_root_mean_squared_error: 1.6733 - learning_rate: 0.0012
# Epoch 47/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6603 - mae: 0.7763 - root_mean_squared_error: 4.2627 - val_loss: 0.6455 - val_mae: 0.8000 - val_root_mean_squared_error: 3.2880 - learning_rate: 0.0012
# Epoch 48/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6222 - mae: 0.7631 - root_mean_squared_error: 3.8147 - val_loss: 0.3003 - val_mae: 0.3513 - val_root_mean_squared_error: 1.9713 - learning_rate: 0.0012
# Epoch 49/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6030 - mae: 0.7263 - root_mean_squared_error: 3.7820 - val_loss: 0.6935 - val_mae: 0.8428 - val_root_mean_squared_error: 4.4990 - learning_rate: 0.0012
# Epoch 50/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.5460 - mae: 0.6761 - root_mean_squared_error: 3.1782 - val_loss: 0.3175 - val_mae: 0.3541 - val_root_mean_squared_error: 2.1817 - learning_rate: 0.0012
# Epoch 51/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5634 - mae: 0.6878 - root_mean_squared_error: 3.3571 - val_loss: 0.3651 - val_mae: 0.5232 - val_root_mean_squared_error: 1.9276 - learning_rate: 0.0012
# Epoch 52/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6322 - mae: 0.7534 - root_mean_squared_error: 4.3588 - val_loss: 0.6759 - val_mae: 0.7980 - val_root_mean_squared_error: 2.9068 - learning_rate: 0.0012
# Epoch 53/300
# 192/200 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5863 - mae: 0.7003 - root_mean_squared_error: 3.9729
# Epoch 53: ReduceLROnPlateau reducing learning rate to 0.0006249999860301614.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5880 - mae: 0.7022 - root_mean_squared_error: 3.9923 - val_loss: 0.4391 - val_mae: 0.5850 - val_root_mean_squared_error: 1.3664 - learning_rate: 0.0012
# Epoch 54/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5895 - mae: 0.7002 - root_mean_squared_error: 4.2220 - val_loss: 0.4675 - val_mae: 0.6301 - val_root_mean_squared_error: 3.3872 - learning_rate: 6.2500e-04
# Epoch 55/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5286 - mae: 0.6204 - root_mean_squared_error: 3.6043 - val_loss: 0.4270 - val_mae: 0.5498 - val_root_mean_squared_error: 2.5489 - learning_rate: 6.2500e-04
# Epoch 56/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5327 - mae: 0.6348 - root_mean_squared_error: 3.8772 - val_loss: 0.3976 - val_mae: 0.4983 - val_root_mean_squared_error: 2.7672 - learning_rate: 6.2500e-04
# Epoch 57/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5369 - mae: 0.6408 - root_mean_squared_error: 3.8087 - val_loss: 0.3626 - val_mae: 0.4809 - val_root_mean_squared_error: 2.6804 - learning_rate: 6.2500e-04
# Epoch 58/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5123 - mae: 0.6254 - root_mean_squared_error: 3.6729 - val_loss: 0.5609 - val_mae: 0.7297 - val_root_mean_squared_error: 1.9234 - learning_rate: 6.2500e-04
# Epoch 59/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.5019 - mae: 0.6229 - root_mean_squared_error: 3.1898 - val_loss: 0.7041 - val_mae: 0.8318 - val_root_mean_squared_error: 4.8830 - learning_rate: 6.2500e-04
# Epoch 60/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5646 - mae: 0.6640 - root_mean_squared_error: 4.1349 - val_loss: 0.4584 - val_mae: 0.5939 - val_root_mean_squared_error: 2.0253 - learning_rate: 6.2500e-04
# Epoch 61/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.4821 - mae: 0.5775 - root_mean_squared_error: 3.4654 - val_loss: 0.6354 - val_mae: 0.8141 - val_root_mean_squared_error: 1.9668 - learning_rate: 6.2500e-04
# Epoch 62/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5591 - mae: 0.6699 - root_mean_squared_error: 4.1851 - val_loss: 0.6604 - val_mae: 0.8198 - val_root_mean_squared_error: 1.9250 - learning_rate: 6.2500e-04
# Epoch 63/300
# 193/200 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5148 - mae: 0.6280 - root_mean_squared_error: 3.7219
# Epoch 63: ReduceLROnPlateau reducing learning rate to 0.0003124999930150807.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5140 - mae: 0.6272 - root_mean_squared_error: 3.7155 - val_loss: 0.3324 - val_mae: 0.4517 - val_root_mean_squared_error: 1.5336 - learning_rate: 6.2500e-04
# Epoch 64/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5315 - mae: 0.6277 - root_mean_squared_error: 4.1925 - val_loss: 0.5415 - val_mae: 0.6495 - val_root_mean_squared_error: 1.4789 - learning_rate: 3.1250e-04
# Epoch 65/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4653 - mae: 0.5518 - root_mean_squared_error: 3.3064 - val_loss: 0.3583 - val_mae: 0.4499 - val_root_mean_squared_error: 1.2643 - learning_rate: 3.1250e-04
# Epoch 66/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4360 - mae: 0.5259 - root_mean_squared_error: 3.0236 - val_loss: 0.4196 - val_mae: 0.5133 - val_root_mean_squared_error: 1.4130 - learning_rate: 3.1250e-04
# Epoch 67/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4362 - mae: 0.5284 - root_mean_squared_error: 3.1353 - val_loss: 0.4311 - val_mae: 0.5495 - val_root_mean_squared_error: 1.3768 - learning_rate: 3.1250e-04
# Epoch 68/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4547 - mae: 0.5433 - root_mean_squared_error: 3.4033 - val_loss: 0.5384 - val_mae: 0.7293 - val_root_mean_squared_error: 1.4998 - learning_rate: 3.1250e-04
# Epoch 69/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4273 - mae: 0.5307 - root_mean_squared_error: 2.9861 - val_loss: 0.3941 - val_mae: 0.5345 - val_root_mean_squared_error: 1.9219 - learning_rate: 3.1250e-04
# Epoch 70/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.4955 - mae: 0.5952 - root_mean_squared_error: 3.5905 - val_loss: 0.3075 - val_mae: 0.4703 - val_root_mean_squared_error: 1.2228 - learning_rate: 3.1250e-04
# Epoch 71/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.4369 - mae: 0.5322 - root_mean_squared_error: 3.2504 - val_loss: 0.4931 - val_mae: 0.6294 - val_root_mean_squared_error: 1.3878 - learning_rate: 3.1250e-04
# Epoch 72/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4329 - mae: 0.5327 - root_mean_squared_error: 2.7015 - val_loss: 0.2467 - val_mae: 0.3477 - val_root_mean_squared_error: 1.3494 - learning_rate: 3.1250e-04
# Epoch 73/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4762 - mae: 0.5701 - root_mean_squared_error: 3.5087 - val_loss: 0.3916 - val_mae: 0.4965 - val_root_mean_squared_error: 2.3417 - learning_rate: 3.1250e-04
# Epoch 74/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4182 - mae: 0.5119 - root_mean_squared_error: 3.0138 - val_loss: 0.3552 - val_mae: 0.4553 - val_root_mean_squared_error: 1.2656 - learning_rate: 3.1250e-04
# Epoch 75/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4237 - mae: 0.5113 - root_mean_squared_error: 3.0481 - val_loss: 0.7011 - val_mae: 0.8607 - val_root_mean_squared_error: 1.7916 - learning_rate: 3.1250e-04
# Epoch 76/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4167 - mae: 0.5268 - root_mean_squared_error: 2.5452 - val_loss: 0.4270 - val_mae: 0.5391 - val_root_mean_squared_error: 1.2488 - learning_rate: 3.1250e-04
# Epoch 77/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4368 - mae: 0.5287 - root_mean_squared_error: 3.1950 - val_loss: 0.3743 - val_mae: 0.5218 - val_root_mean_squared_error: 1.2830 - learning_rate: 3.1250e-04
# Epoch 78/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4135 - mae: 0.5149 - root_mean_squared_error: 2.8053 - val_loss: 0.3485 - val_mae: 0.4923 - val_root_mean_squared_error: 1.5833 - learning_rate: 3.1250e-04
# Epoch 79/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3925 - mae: 0.4942 - root_mean_squared_error: 2.5515 - val_loss: 0.4619 - val_mae: 0.6148 - val_root_mean_squared_error: 1.2598 - learning_rate: 3.1250e-04
# Epoch 80/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.4769 - mae: 0.5900 - root_mean_squared_error: 3.5284 - val_loss: 0.4893 - val_mae: 0.6270 - val_root_mean_squared_error: 1.5459 - learning_rate: 3.1250e-04
# Epoch 81/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.4674 - mae: 0.5688 - root_mean_squared_error: 3.5801 - val_loss: 0.4834 - val_mae: 0.6947 - val_root_mean_squared_error: 1.6946 - learning_rate: 3.1250e-04
# Epoch 82/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4146 - mae: 0.5124 - root_mean_squared_error: 2.9765
# Epoch 82: ReduceLROnPlateau reducing learning rate to 0.00015624999650754035.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.4145 - mae: 0.5122 - root_mean_squared_error: 2.9751 - val_loss: 0.4816 - val_mae: 0.6319 - val_root_mean_squared_error: 2.4603 - learning_rate: 3.1250e-04
# Epoch 83/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4393 - mae: 0.5249 - root_mean_squared_error: 3.2145 - val_loss: 0.4136 - val_mae: 0.5364 - val_root_mean_squared_error: 1.2898 - learning_rate: 1.5625e-04
# Epoch 84/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4014 - mae: 0.4814 - root_mean_squared_error: 2.9192 - val_loss: 0.4482 - val_mae: 0.5642 - val_root_mean_squared_error: 1.4135 - learning_rate: 1.5625e-04
# Epoch 85/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3962 - mae: 0.4815 - root_mean_squared_error: 3.0178 - val_loss: 0.5071 - val_mae: 0.6357 - val_root_mean_squared_error: 1.3341 - learning_rate: 1.5625e-04
# Epoch 86/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3731 - mae: 0.4622 - root_mean_squared_error: 2.4053 - val_loss: 0.3162 - val_mae: 0.4099 - val_root_mean_squared_error: 1.3179 - learning_rate: 1.5625e-04
# Epoch 87/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4129 - mae: 0.4926 - root_mean_squared_error: 3.1539 - val_loss: 0.3597 - val_mae: 0.5236 - val_root_mean_squared_error: 1.7272 - learning_rate: 1.5625e-04
# Epoch 88/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4097 - mae: 0.4975 - root_mean_squared_error: 3.1522 - val_loss: 0.3829 - val_mae: 0.5178 - val_root_mean_squared_error: 1.8102 - learning_rate: 1.5625e-04
# Epoch 89/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3643 - mae: 0.4422 - root_mean_squared_error: 2.5705 - val_loss: 0.5042 - val_mae: 0.6619 - val_root_mean_squared_error: 1.4775 - learning_rate: 1.5625e-04
# Epoch 90/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4527 - mae: 0.5433 - root_mean_squared_error: 3.5315 - val_loss: 0.4885 - val_mae: 0.6568 - val_root_mean_squared_error: 1.5037 - learning_rate: 1.5625e-04
# Epoch 91/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3994 - mae: 0.4902 - root_mean_squared_error: 2.5745 - val_loss: 0.3438 - val_mae: 0.4562 - val_root_mean_squared_error: 2.0922 - learning_rate: 1.5625e-04
# Epoch 92/300
# 196/200 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3753 - mae: 0.4571 - root_mean_squared_error: 2.7695
# Epoch 92: ReduceLROnPlateau reducing learning rate to 7.812499825377017e-05.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3759 - mae: 0.4579 - root_mean_squared_error: 2.7762 - val_loss: 0.3237 - val_mae: 0.4657 - val_root_mean_squared_error: 1.6933 - learning_rate: 1.5625e-04
# Epoch 93/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4000 - mae: 0.4781 - root_mean_squared_error: 3.1938 - val_loss: 0.3923 - val_mae: 0.5353 - val_root_mean_squared_error: 1.4883 - learning_rate: 7.8125e-05
# Epoch 94/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4235 - mae: 0.5047 - root_mean_squared_error: 3.0183 - val_loss: 0.3690 - val_mae: 0.4714 - val_root_mean_squared_error: 1.3546 - learning_rate: 7.8125e-05
# Epoch 95/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4044 - mae: 0.4819 - root_mean_squared_error: 3.0788 - val_loss: 0.3397 - val_mae: 0.4786 - val_root_mean_squared_error: 1.3625 - learning_rate: 7.8125e-05
# Epoch 96/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3562 - mae: 0.4284 - root_mean_squared_error: 2.5678 - val_loss: 0.3660 - val_mae: 0.4890 - val_root_mean_squared_error: 1.1914 - learning_rate: 7.8125e-05
# Epoch 97/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4007 - mae: 0.4825 - root_mean_squared_error: 3.1382 - val_loss: 0.4083 - val_mae: 0.5331 - val_root_mean_squared_error: 1.5021 - learning_rate: 7.8125e-05
# Epoch 98/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4135 - mae: 0.4950 - root_mean_squared_error: 3.1717 - val_loss: 0.4487 - val_mae: 0.5571 - val_root_mean_squared_error: 1.3034 - learning_rate: 7.8125e-05
# Epoch 99/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4145 - mae: 0.4868 - root_mean_squared_error: 3.2996 - val_loss: 0.4535 - val_mae: 0.5710 - val_root_mean_squared_error: 1.3458 - learning_rate: 7.8125e-05
# Epoch 100/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4009 - mae: 0.4767 - root_mean_squared_error: 3.0711 - val_loss: 0.3480 - val_mae: 0.4505 - val_root_mean_squared_error: 1.3200 - learning_rate: 7.8125e-05
# Epoch 101/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3728 - mae: 0.4447 - root_mean_squared_error: 2.8028 - val_loss: 0.4397 - val_mae: 0.5952 - val_root_mean_squared_error: 1.6506 - learning_rate: 7.8125e-05
# Epoch 102/300
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4048 - mae: 0.4868 - root_mean_squared_error: 3.0505
# Epoch 102: ReduceLROnPlateau reducing learning rate to 3.9062499126885086e-05.
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.4049 - mae: 0.4869 - root_mean_squared_error: 3.0519 - val_loss: 0.3658 - val_mae: 0.4960 - val_root_mean_squared_error: 1.4458 - learning_rate: 7.8125e-05
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# Model Metrics:
# - MAE: 0.3477 ml
# - R²: 0.9996
# Saved artifact at '/tmp/tmp2ztuyxy_'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 8), dtype=tf.float32, name='keras_tensor_202')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   139136712724112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139136712727184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139136712727568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139136712735824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139136712734480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139136712729296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139136712736208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139136712726416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139136712734864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139136712723920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139136712736016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   139136712724496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#
# Model size: 48444 bytes
# 0
